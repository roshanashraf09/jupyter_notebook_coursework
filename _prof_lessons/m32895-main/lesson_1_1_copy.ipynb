# %% [markdown]
# <a href="https://colab.research.google.com/github/DrSYakovlev/m32895-public-tb2-2026/blob/main/lesson_1_1_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lesson_1.1**
# ### (*Introduction*)

# %% [markdown]
# ## In this lecture

# %% [markdown]
# * About your lecturer
#
# * The TB/module structure
# * **Assessment**
# * Setting up your GitHub account and creating code repository
# * Create cloud codespace
# * Interaction between [Github](https://github.com/) and [VS Code](https://code.visualstudio.com/)
# * [Jupyter Notebook](https://jupyter.org/)
# * [markdown](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) syntax
# * [Kaggle](https://www.kaggle.com/)
# * Reflection on what are ***'(big) data'*** and why do we need those?
# * Why Python?
# * `print()` function
# * Declaring variables
# * `input()` function
# * Homework
# * Of course: what about ChatGPT or other A.I. tools?
# * **Before we finish - the most important thing**

# %% [markdown]
# ---

# %% [markdown]
# ## TB/module structure
# * No hard coding. Python fundamentals and essentials specific and sufficient for **big data** applications
#
# * 2 classes per week, 2 hours each class. N.b. Each class will cover it's own topic or continues a previous one! **Meaning, both classes in a week need to be attended**
# * Lecture numbering: in **lesson_1.1** the 1<sup>st</sup> number is the week number; the 2<sup>nd</sup> number is the lecture of the week. Each tutorial has dedicated Jupyter Notebook

# %% [markdown]
# ---

# %% [markdown]
# ## Assessment
# 1. Set of exercises: **20%**
#
# 2. Course work with **viva**: **80%**
#
# Submission dates: **t.b.d.**

# %% [markdown]
# ---

# %% [markdown]
# ## Setting up your GitHub account and creating code repository
# *(Follow in-class instructions)*
#
# * Visit **[https://github.com/](https://github.com/)** and create an account
# * N.b. Do not login using your Google profile. Create a proper password and memorise it or write it down. You will need this password to provide third-party services access to your github account
# * Create GitHub repository
# 	* Give sensible name
# 	* Make it public
# 	* Add README file
# 	* add .gitignore from Python template
# 	* Licence is not required
# 	* *You can customise your page later by adding photo, bio etc*
# 	* Finally click on the green **"Create repository"** button. Do not just hit "Enter"

# %% [markdown]
# ---

# %% [markdown]
# ## Create cloud codespace
# *(follow in-class instructions)*
#
# * In your repository, click **"<> Code"** button and select **"Codespaces"** tab
# * Click on the **"Create codespace on main"** green button; the process may take a min or two
# * In the file tab of VS Code select **"Autosave"**
# * Optional: in your codespace, click on **Settings** (gear icon in the bottom left corner) -> **Themes** -> **Color Theme** and select color theme you prefer

# %% [markdown]
# ---

# %% [markdown]
# ## Interaction between [Github](https://github.com/) and [VS Code](https://code.visualstudio.com/)
# ![GitHub-IDE interaction](https://github.com/DrSYakovlev/m32895-public-tb2-2026/blob/main/assets/img/lesson_1.1_github-ide.jpg?raw=1)
#
# * Codespace can be deleted and re-created. No data would be lost as far as GitHub repo is being kept updated - more on in in the next lecture

# %% [markdown]
# ---

# %% [markdown]
# ## Jupyter Notebook
# Our main development tool from now on
#
# This is also a format of your assessment and CW submission
#
# * In the project explorer on the left side, right-click -> "**New Folder..."**, give the folder a name "jupyter_notebooks"
# * Open this folder, then create a file with a sensible name and an extension **.ipynb**
# * In your new Jupyter Notebook click **"Select Kernel"** (top right corner) -> **Install/Enable suggested extensions Python + Jupyter** -> **Python Environments...** -> select available Python version
# * Upon the first `Code` cell execution, you will be asked to install Python kernel. Follow the in-class instructions (installation can take a while)
# *The name of the **Jupyter** project is the melt of names of three supported languages: <u>Julia, Python and R</u>. Jupyter notebook can also be run via Jupyter project, Anaconda or Google Colab*. VS Code is a universal IDE, can handle any other programming language and we are going to use it in this course

# %% [markdown]
# ---

# %% [markdown]
# ## [Markdown](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) syntax
# * Very simple and extremely powerful
# * Everything in this ipynb file (and following) is formatted using the Markdown syntax
# * You will use this extensively in your exercise portfolio, CW and README
#
# <u>Examples:</u> *(Click on the cell below to see how the syntax is being used)*

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6
# * Unordered list
# 	* Nested list
# 1. Ordered list
#
# *italic*
#
# **bold**
#
# ~~deletion~~
#
# > Quote
#
# `code line`
#
# ```
# Multiline
# code
# snippet
# ```
# `![image](link to the image)`
# `[link to...](URL)`
#
# - [x] Action 1
# - [ ] Action 2
# - [ ] Action 3
#
# And many more... like tables, adding colors, internal references, subscript and superscript indices...
#
# Even supports some **HTML** for more flexibility and control!
# ```
# <p align="center">
# <img src="../assets/img/lesson_1.1_lin-regr-example.jpg" width="600">
# </p>
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## [Kaggle](https://www.kaggle.com/)
# Sign-up and explore a bit. More on it later...

# %% [markdown]
# ---

# %% [markdown]
# ## What are 'Big Data' and why do we need them? (some basic definitions)
# *Data **is** or data **are**, by the way?*
# * The term **data** refers to items of information that describe a (qualitative) status or a (quantitative) measure of magnitude
#
# * **Big data** consists of extremely large *data sets* that can best be analyzed by computer to reveal pattern and trend insights
#
# * **Data analysis** (a.k.a. "data analytics") is the practice of converting collected data into the information that is useful for <u>decision-making</u>
#
# * **Data science** is the study of how data can be turned into a valuable resource
#
# * **Data mining** is the process of searching large datasets to identify patterns
#
# * **Data product** is digital information that can be purchased
#
# The simplest example - what do we see here?:
#
# <p align="center">
# <img src="https://github.com/DrSYakovlev/m32895-public-tb2-2026/blob/main/assets/img/lesson_1.1_lin-regr-example.jpg?raw=1" width="600">
# </p>

# %% [markdown]
# ---

# %% [markdown]
# ## Why Python?
# * High-level programming language
#
# * Very clear syntax
# * Interpreted
# * Dynamically typed
# * Abundance of libraries for data handling, visualisation and modelling (we do not have much choice when it comes to data analysis and machine learning)

# %% [markdown]
# ---

# %% [markdown]
# ## Input / Output in Python

# %%
# It is an old tradition to begin with:
print('Hello, World!')

# %% [markdown]
# #### `print()` function

# %%
print("test message")  # Printing string
print(2 + 2) # Printing result of equation
week_day = "Monday"
print(f"Today is {week_day}")  # String literals

# %% [markdown]
# ---

# %% [markdown]
# ### Declaring variables
# `=` assignment operator

# %%
a = 5  # think of it as a storage box and your variable is a lable
my_name = "Sergey"
my_object = {
    "flat": 20,
    "type": "residential"
}
my_list = [3, 5, 6.4]

# %% [markdown]
# ---

# %% [markdown]
# #### `input()` function

# %%
a = input('tell me something')

# %%
print("You've just entered", a)
# or
a # Variable will be shown like this if last line in a code cell

# %% [markdown]
# ---

# %% [markdown]
# ## Homework
# * Study the structure and options of **GitHub**
#
# * Get familiar with **VS Code codespace**
# * Get familiar with **Jupyter Notebook**
# * Get familiar with **markdown** synthax
# * Practice with different applications of `print()` and `input()` statements

# %% [markdown]
# ---

# %% [markdown]
# ## ChatGPT or other A.I. tools
# Not allowed

# %% [markdown]
# ---

# %% [markdown]
# ## Before we finish - the most important thing
# #### 'End of session' routine. Good practice - run this set of commands regularly for back up and version control.
# * Open terminal
# * `git status` - to see commit status (check uncommitted changes to your project)
# * Clear all cell output (there is a corresponding button above)
# * Update .gitignore file (more on it later...)
# * `git add --all`
# * `git commit -m "commit message"`
# * `git push`
# * Refresh your GitHub repository page to check that all changes are committed and pushed. Well done - you successfully committed your code to GitHub.

# %% [markdown]
# ---
